# %%
import matplotlib.pyplot as plt
from astroquery.gaia import Gaia
import pandas as pd
import numpy as np
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
d = pd.read_csv("data/planets.csv")

# Print the first few rows of the DataFrame
print(d.info())

Gaia.ROW_LIMIT = 10000

# print the row with the planet name: "Earth"

planet = d[d["pl_name"] == "Kepler-1176 b"]

print(planet)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5514 entries, 0 to 5513
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pl_name         5514 non-null   object
#  1   hostname        5514 non-null   object
#  2   sy_snum         5514 non-null   int64
#  3   sy_pnum         5514 non-null   int64
#  4   disc_facility   5514 non-null   object
#  5   disc_telescope  5514 non-null   object
#  6   pl_orbper       5271 non-null   float64
#  7   pl_orbsmax      5217 non-null   float64
#  8   pl_rade         5495 non-null   float64
#  9   pl_radj         5494 non-null   float64
#  10  pl_bmasse       5488 non-null   float64
#  11  pl_bmassj       5488 non-null   float64
#  12  pl_bmassprov    5514 non-null   object
#  13  pl_dens         5402 non-null   float64
#  14  pl_orbeccen     4749 non-null   float64
#  15  pl_insol        3834 non-null   float64
#  16  pl_eqt          4072 non-null   float64
#  17  pl_orbincl      4224 non-null   float64
#  18  ttv_flag        5514 non-null   int64
#  19  pl_imppar       3998 non-null   float64
#  20  pl_orblper      1596 non-null   float64
#  21  st_spectype     1969 non-null   object
#  22  st_teff         5301 non-null   float64
#  23  st_mass         5510 non-null   float64
#  24  st_lum          5285 non-null   float64
#  25  st_logg         5273 non-null   float64
#  26  rastr           5514 non-null   object
#  27  ra              5514 non-null   float64
#  28  decstr          5514 non-null   object
#  29  dec             5514 non-null   float64
#  30  sy_dist         5493 non-null   float64
#  31  sy_vmag         5301 non-null   float64
#  32  sy_kmag         5305 non-null   float64
#  33  sy_gaiamag      5250 non-null   float64
#  34  sy_gaiamagerr1  5248 non-null   float64
#  35  sy_gaiamagerr2  5248 non-null   float64
# dtypes: float64(25), int64(3), object(8)
# memory usage: 1.5+ MB
# None
#             pl_name     hostname  sy_snum  sy_pnum disc_facility  \
# 2188  Kepler-1176 b  Kepler-1176        1        1        Kepler
#
#                disc_telescope  pl_orbper  pl_orbsmax  pl_rade  pl_radj  ...  \
# 2188  0.95 m Kepler Telescope  24.173858      0.1589     2.45    0.219  ...
#
#              rastr          ra         decstr        dec  sy_dist  sy_vmag  \
# 2188  19h51m40.73s  297.919724  +45d16m27.13s  45.274204  864.699    15.27
#
#       sy_kmag  sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2
# 2188    13.31     15.0496        0.000415       -0.000415
#
# [1 rows x 36 columns]

# %%
from astropy.coordinates import CartesianRepresentation

target_ra = planet["ra"].values[0]
target_dec = planet["dec"].values[0]
target_distance = planet["sy_dist"].values[0]

print(target_ra)
print(target_dec)
print(target_distance)

# Step 3: Create a SkyCoord object using the Cartesian coordinates

# # Step 4: Access the spherical properties (RA, Dec, and Distance)
# ra = sky_coord.ra           # Right Ascension in degrees
# dec = sky_coord.dec         # Declination in degrees
# distance = sky_coord.distance  # Distance in parsecs
# 
# target_coord = SkyCoord(ra=target_ra * u.deg, dec=target_dec * u.deg, distance=target_distance * u.pc, frame='icrs')

cartesian_rep = CartesianRepresentation(x=284.92103781, y=-537.67453369, z=614.35369181)

target_coord = SkyCoord(cartesian_rep, frame='icrs')

# round the values to 2 decimal places
target_ra = round(target_coord.ra.deg, 2)  # Right Ascension in degrees
target_dec = round(target_coord.dec.deg, 2)  # Declination in degrees
target_distance = target_coord.distance

print(target_ra)
print(target_dec)
print(target_distance)
# Out:
# 297.919724
# 45.2742038
# 864.699
# 297.92
# 45.27
# 864.6990000029275

# %%
search_distance = 500 # distance in parsecs around the target planet
search_distance = min(search_distance, target_distance)
search_radius = np.arcsin(search_distance/np.sqrt((target_distance-search_distance)**2 + search_distance**2)) * 180/np.pi
max_mag = 10

query = f"""
SELECT
  source_id, ra, dec, parallax, pmra, pmdec, phot_g_mean_mag
FROM gaiadr3.gaia_source
WHERE
  ABS(1000/parallax - {target_distance}) < {search_distance}
  AND 
  1=CONTAINS(
    POINT('ICRS',ra,dec),
    CIRCLE('ICRS',{target_ra},{target_dec},{search_radius})
  )
  AND phot_g_mean_mag <= {max_mag}
  AND parallax IS NOT NULL
  ORDER BY distance_gspphot ASC
"""


job = Gaia.launch_job_async(query)

star_data = []

raw_data = job.get_results()

for row in raw_data:
    distance = 1000 / row["parallax"]

    star = {
        "ra": row["ra"],
        "dec": row["dec"],
        "distance": distance,
        "magnitude": row["phot_g_mean_mag"]
    }
    star_data.append(star)
# Out:
# 500 Error 500:
# null
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[76], line 23
#       4 max_mag = 10
#       6 query = f"""
#       7 SELECT
#       8   source_id, ra, dec, parallax, pmra, pmdec, phot_g_mean_mag
#    (...)
#      19   ORDER BY distance_gspphot ASC
#      20 """
# ---> 23 job = Gaia.launch_job_async(query)
#      25 star_data = []
#      27 raw_data = job.get_results()
#
# File ~\PycharmProjects\testExosky\.venv\Lib\site-packages\astroquery\gaia\core.py:1021, in GaiaClass.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     980 def launch_job_async(self, query, *, name=None, output_file=None,
#     981                      output_format="votable_gzip", verbose=False,
#     982                      dump_to_file=False, background=False,
#     983                      upload_resource=None, upload_table_name=None,
#     984                      autorun=True):
#     985     """Launches an asynchronous job
#     986
#     987     Parameters
#    (...)
#    1019     A Job object
#    1020     """
# -> 1021     return TapPlus.launch_job_async(self, query=query,
#    1022                                     name=name,
#    1023                                     output_file=output_file,
#    1024                                     output_format=output_format,
#    1025                                     verbose=verbose,
#    1026                                     dump_to_file=dump_to_file,
#    1027                                     background=background,
#    1028                                     upload_resource=upload_resource,
#    1029                                     upload_table_name=upload_table_name,
#    1030                                     autorun=autorun,
#    1031                                     format_with_results_compressed=('votable_gzip', 'fits', 'ecsv'))
#
# File ~\PycharmProjects\testExosky\.venv\Lib\site-packages\astroquery\utils\tap\core.py:480, in Tap.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun, maxrec, format_with_results_compressed)
#     478                 job.save_results(verbose=verbose)
#     479             else:
# --> 480                 job.get_results()
#     481                 log.info("Query finished.")
#     482 return job
#
# File ~\PycharmProjects\testExosky\.venv\Lib\site-packages\astroquery\utils\tap\model\job.py:242, in Job.get_results(self)
#     239     return None
#     240 else:
#     241     # async: result is in the server once the job is finished
# --> 242     self.__load_async_job_results()
#     243     return self.results
#
# File ~\PycharmProjects\testExosky\.venv\Lib\site-packages\astroquery\utils\tap\model\job.py:348, in Job.__load_async_job_results(self, debug)
#     343     print(resultsResponse.getheaders())
#     345 resultsResponse = self.__handle_redirect_if_required(resultsResponse,
#     346                                                      verbose=debug)
#     347 isError = self.connHandler.\
# --> 348     check_launch_response_status(resultsResponse,
#     349                                  debug,
#     350                                  200)
#     351 self._phase = phase
#     352 if phase == 'ERROR':
#
# File ~\PycharmProjects\testExosky\.venv\Lib\site-packages\astroquery\utils\tap\conn\tapconn.py:672, in TapConn.check_launch_response_status(self, response, debug, expected_response_status, raise_exception)
#     670     errMsg = taputils.get_http_response_error(response)
#     671     print(response.status, errMsg)
# --> 672     raise requests.exceptions.HTTPError(errMsg)
#     673 else:
#     674     return isError
#
# HTTPError: Error 500:
# null

# %%
star_coords = SkyCoord(
    ra=[star["ra"] for star in star_data] * u.deg,
    dec=[star["dec"] for star in star_data] * u.deg,
    distance=[star["distance"] for star in star_data] * u.pc,
    frame='icrs'
)

target_x, target_y, target_z = target_coord.cartesian.xyz.value
zstar_x = star_coords.cartesian.x.value
zstar_y = star_coords.cartesian.y.value
zstar_z = star_coords.cartesian.z.value

star_x = []
star_y = []
star_z = []

magnitudes = [star["magnitude"] for star in star_data]

star_magnitudes = []

i = 0
j=1
for star in star_data:
    # check if the star is within the distance range to the target
    if (zstar_x[i] - target_x)**2 + (zstar_y[i] - target_y)**2 + (zstar_z[i] - target_z)**2 < search_distance**2:  
        star_x.append(zstar_x[i])
        star_y.append(zstar_y[i])
        star_z.append(zstar_z[i])
        star_magnitudes.append(magnitudes[i])
        j += 1
    i += 1
    
# Creating a DataFrame
data = {'x': star_x, 'y': star_y, 'z': star_z, 'magnitude': star_magnitudes}
df = pd.DataFrame(data)

df.to_csv("data/stars.csv", index=False)


# Print the first few stars
print("Star data:", j)
# Out:
# Star data: 16095

# %%
import plotly.graph_objs as go

max_range = max(
    np.max(star_x) - target_x, np.max(star_y) - target_y, np.max(star_z) - target_z,
    target_x - np.min(star_x), target_y - np.min(star_y), target_z - np.min(star_z)
)

# Set limits for each axis centered on the target
x_limits = [target_x - max_range, target_x + max_range]
y_limits = [target_y - max_range, target_y + max_range]
z_limits = [target_z - max_range, target_z + max_range]

# Create the central target trace
target_trace = go.Scatter3d(
    x=[target_x], y=[target_y], z=[target_z],
    mode='markers',
    marker=dict(size=10, color='red'),
    name='Central Target'
)

# Create the star cloud trace
star_trace = go.Scatter3d(
    x=star_x, y=star_y, z=star_z,
    mode='markers',
    marker=dict(size=5, color='blue'),
    name='Stars'
)

# Define layout with manually set axis limits for equal scaling
layout = go.Layout(
    title='3D Star Field Around Target (Equal Scaling)',
    scene=dict(
        xaxis=dict(title='X (parsecs)', range=x_limits),
        yaxis=dict(title='Y (parsecs)', range=y_limits),
        zaxis=dict(title='Z (parsecs)', range=z_limits),
        aspectmode='manual',
        aspectratio=dict(x=1, y=1, z=1)  # Enforces equal scaling on all axes
    ),
)

# Create the figure
fig = go.Figure(data=[target_trace, star_trace], layout=layout)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="3174981c-63b5-4c1b-83ac-e3988da405ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3174981c-63b5-4c1b-83ac-e3988da405ed")) {                    Plotly.newPlot(                        "3174981c-63b5-4c1b-83ac-e3988da405ed",                        [{"marker":{"color":"red","size":10},"mode":"markers","name":"Central Target","x":[12.000000000000002],"y":[12.000000000000002],"z":[12.0],"type":"scatter3d"},{"marker":{"color":"blue","size":5},"mode":"markers","name":"Stars","x":[-184.97883383926597,-180.8903333942903,102.4263438123061,81.13743615903013,-63.77442726805178,167.06685264372626,169.39441436108066,293.0017246669092,311.64719926806936,270.06959783314227,123.45174259723294,297.3653724817708,-6.909515215783403,128.69819088364653,251.36819878134241,105.42976417502678,4.580820162243105,306.00746124444953,307.7276829415598,92.25449861815046,278.86432589361414,224.03735442124702,331.2834841467929,331.0802157877761,177.50954558808783,-110.01016180411624,88.78859839745702,125.12887001225126,157.31901363708153,111.6414199244238,216.6736595715567,160.42841978052613,226.52147736266392,224.56187604740356,178.6270767435348,159.78100112583567,198.02122045491492,323.3402192544764,121.06388868823572,169.9522257408547,129.09277710861986,331.32514439927866,214.92661641853155,251.2334027027656,167.45681057451895,215.19307081793042,9.79252660528864,319.1844164968793,285.8568094705827,55.16040372338347,118.84429114756665,191.6660977464991,268.0304887479624,127.37291951018577,193.50920851402114,147.62692351042074,101.3612394352654,-196.28460651682383,179.4201221266887,73.53863226859666,226.5653273720178,-35.40680390132611,316.8998729528151,104.80022446706481,-66.71785713273268,348.91910165106896,406.6135730650922,170.78655036759503,-176.1601748108145,155.2434722016024,-95.48294647482442,143.30831513052038,90.54356445769515,364.9199192131245,274.19572957156976,26.8354001550692,-58.96918868285516,194.04927336888952,163.367235268214,110.87097290247985,330.93971631392077,92.6833693882763,79.96676785167183,233.07967072567374,-106.69990949639849,227.6668391286346,43.98298432421462,283.3631829774826,90.4718948004276,183.05936536380457,199.1612309271835,230.96099969464152,53.1149740920044,-104.23462317249479,14.397538848028764,69.89207385141167,244.2488465519909,195.4024309768958,250.7097169212547,219.84463031667215,213.45287920284,318.9857417077935,89.71734505971183,-31.85591441079083,389.9225349381888,221.54023519227326,180.4360699043327,294.3883688522137,303.3250747571177,351.03998490347146,-26.375799926869373,-76.89937213598373,-28.436451853813285,45.9014590985048,276.21897564933676,146.59736273091232,187.95382333080076,58.76392049845398,167.19812254441464,114.1438424722296,152.88735059307072,298.48277120947535,113.19114879979045,-83.01107693069504,301.2556187745151,139.41210581765384,343.41084080656947,209.27922084192707,139.89024363207602,229.78183675214015,45.46385037040466,-0.6979516351635306,247.28056893498677,89.25273737920743,223.27634983689316,227.32722594421435,313.5995829878439,194.90679526323194,280.21547438935187,-66.81872704709342,285.8739944841056,198.47988240983423,292.9223972486455,131.02263722301456,207.35213733559118,72.20298473146572,310.49239105007445,145.43685695674688,280.65493578482807,-14.95313403749604,100.73485417134371,172.3912997093356,82.7342385151686,219.38000368380952,179.02631545778,366.71924594495755,160.11502552791737,91.35006167309925,338.8628992519742,61.443363466851146,-32.46729202537986,263.596268984695,324.03110060333785,128.44831434016547,105.33438045054626,120.75838817816796,218.8652280511842,277.3714236085471,59.885752198776295,197.39005357376303,28.182611795504087,190.74649089169534,312.962213205946,250.32341955732903,139.24755 ...

# %%
# 2d scatter plot

plt.scatter(star_x, star_y, c='blue', s=5)

# %%
def get_stars(x: int | float, y: int | float, z: int | float, search_distance: int | float = 200):
        cartesian_rep = CartesianRepresentation(x=x, y=y, z=z)

        # Step 3: Create a SkyCoord object using the Cartesian coordinates
        target_coord = SkyCoord(cartesian_rep, frame='icrs')

        # Step 4: Access the spherical properties (RA, Dec, and Distance)
        # target_ra = target_coord.ra.deg  # Right Ascension in degrees
        # target_dec = target_coord.dec.deg  # Declination in degrees
        # target_distance = target_coord.distance  # Distance in parsecs
        
        print(target_ra)
        print(target_dec)
        print(target_distance)

        search_distance = min(search_distance, target_distance)
        search_radius = np.arcsin(
            search_distance / np.sqrt((target_distance - search_distance) ** 2 + search_distance ** 2)) * 180 / np.pi
        max_mag = 10

        query = f"""
        SELECT
  source_id, ra, dec, parallax, pmra, pmdec, phot_g_mean_mag
FROM gaiadr3.gaia_source
WHERE
  ABS(1000/parallax - {target_distance}) < {search_distance}
  AND 
  1=CONTAINS(
    POINT('ICRS',ra,dec),
    CIRCLE('ICRS',{target_ra},{target_dec},{search_radius})
  )
  AND phot_g_mean_mag <= {max_mag}
  AND parallax IS NOT NULL
  ORDER BY distance_gspphot ASC
        """

        job = Gaia.launch_job_async(query)

        star_data = []

        raw_data = job.get_results()

        for row in raw_data:
            distance = 1000 / row["parallax"]

            star = {
                "ra": row["ra"],
                "dec": row["dec"],
                "distance": distance
            }
            star_data.append(star)

        star_coords = SkyCoord(
            ra=[star["ra"] for star in star_data] * u.deg,
            dec=[star["dec"] for star in star_data] * u.deg,
            distance=[star["distance"] for star in star_data] * u.pc,
            frame='icrs'
        )

        target_x, target_y, target_z = target_coord.cartesian.xyz.value
        zstar_x = star_coords.cartesian.x.value
        zstar_y = star_coords.cartesian.y.value
        zstar_z = star_coords.cartesian.z.value

        star_x = []
        star_y = []
        star_z = []

        i = 0
        j = 1
        for star in star_data:
            # check if the star is within the distance range to the target
            if (zstar_x[i] - target_x) ** 2 + (zstar_y[i] - target_y) ** 2 + (
                    zstar_z[i] - target_z) ** 2 < search_distance ** 2:
                star_x.append(zstar_x[i])
                star_y.append(zstar_y[i])
                star_z.append(zstar_z[i])
                j += 1
            i += 1

        # Print the first few stars
        print("Star data:", j)
        
get_stars(12, 12, 12, 500)
# Out:
# 297.919724
# 45.2742038
# 864.699
# INFO: Query finished. [astroquery.utils.tap.core]
# Star data: 16095
