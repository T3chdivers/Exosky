# %%
from astropy.coordinates import SkyCoord
from astroquery.gaia import Gaia
from astropy import units as u

Gaia.ROW_LIMIT = 50  # Ensure the default row limit.
coord = SkyCoord(ra=280, dec=-60, unit=(u.degree, u.degree), frame='icrs')
j = Gaia.cone_search_async(coord, radius=u.Quantity(1.0, u.deg))
r = j.get_results()
r.pprint()

r.info()
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
#     solution_id             DESIGNATION          ...          dist
#                                                  ...
# ------------------- ---------------------------- ... ---------------------
# 1636148068921376768 Gaia DR3 6636090334814214528 ... 0.0026043272506261527
# 1636148068921376768 Gaia DR3 6636090339112400000 ... 0.0033616678530916998
# 1636148068921376768 Gaia DR3 6636090339113063296 ... 0.0038498801828703495
# 1636148068921376768 Gaia DR3 6636090339112213760 ...  0.004422603920589843
# 1636148068921376768 Gaia DR3 6636090334814217600 ...  0.004545515007418226
# 1636148068921376768 Gaia DR3 6636089583198816640 ...   0.00561391998241014
# 1636148068921376768 Gaia DR3 6636090334814218752 ...  0.005845777923125324
# 1636148068921376768 Gaia DR3 6636090334814213632 ...  0.006210490970134131
# 1636148068921376768 Gaia DR3 6636090339112308864 ...  0.007466944025525982
#                 ...                          ... ...                   ...
# 1636148068921376768 Gaia DR3 6636089613259710208 ...  0.017605277909941406
# 1636148068921376768 Gaia DR3 6636090437893440640 ...  0.018239488861913372
# 1636148068921376768 Gaia DR3 6636066935832392960 ...  0.019164070819928845
# 1636148068921376768 Gaia DR3 6636089510180765312 ...   0.01943430820674814
# 1636148068921376768 Gaia DR3 6636066871411763712 ...   0.01946443283069129
# 1636148068921376768 Gaia DR3 6636089514475519232 ...   0.01946900331602147
# 1636148068921376768 Gaia DR3 6636090407832546944 ...  0.019751317240143573
# 1636148068921376768 Gaia DR3 6636066940132132352 ...  0.019916769172899054
# 1636148068921376768 Gaia DR3 6636089514478677504 ...  0.019967388048343956
# 1636148068921376768 Gaia DR3 6636066871411763968 ...  0.020149893249057697
# Length = 50 rows
# <Table length=50>
#               name               dtype       unit                                                                  description                                                              n_bad
# ------------------------------- ------- ------------- ------------------------------------------------------------------------------------------------------------------------------------- -----
#                     solution_id   int64                                                                                                                                 Solution Identifier     0
#                     DESIGNATION  object                                                                                         Unique source designation (unique across all Data Releases)     0
#                       SOURCE_ID   int64                                                                                  Unique source identifier (unique within a particular Data Release)     0
#                    random_index   int64                                                                                                         Random index for use when selecting subsets     0
#                       ref_epoch float64            yr                                                                                                                       Reference epoch     0
#                              ra float64           deg                                                                                                                       Right ascension     0
#                        ra_error float32           mas                                                                                                     Standard error of right ascension     0
#                             dec float64           deg                                                                                                                           Declination     0
#                       dec_error float32           mas                                                                                                         Standard error of declination     0
#                        parallax float64           mas                                                                                                                              Parallax     6
#                  parallax_error float32           mas                                                                                                            Standard error of parallax     6
#             parallax_over_error float32                                                                                                              Parallax divided by its standard error     6
#                              pm float32      mas / yr                                                                                                                   Total proper motion     6
#                            pmra float64      mas / yr                                                                                            Proper motion in right ascension direction     6
#                      pmra_error float32      mas / yr                                                                          Standard error of proper motion in right ascension direction     6
#                           pmdec float64      mas / yr                                                                                                Proper motion in declination direction     6
#                     pmdec_error float32      mas / yr                                                                              Standard error of proper motion in declination direction     6
#                     ra_dec_corr float32                                                                                                 Correlation between right ascension and declination     0
#                ra_parallax_corr float32                                                                                                    Correlation between right ascension and parallax     6
#                    ra_pmra_corr float32                                                                            Correlation between right ascension and proper motion in right ascension     6
#                   ra_pmdec_corr float32                                                                                Correlation between right ascension and proper motion in declination     6
#               dec_parallax_corr float32                                                                                                        Correlation between declination and parallax     6
#                   dec_pmra_corr float32                                                                                Correlation between declination and proper motion in right ascension     6
#                  dec_pmdec_corr float32                                                                                    Correlation between declination and proper motion in declination     6
#              parallax_pmra_corr float32                                                                                   Correlation between parallax and proper motion in right ascension     6
#             parallax_pmdec_corr float32                                                                                       Correlation between parallax and proper motion in declination     6
#                 pmra_pmdec_corr float32                                                               Correlation between proper motion in right ascension and proper motion in declination     6
#            astrometric_n_obs_al   int16                                                                                       Total number of observations in the along-scan (AL) direction     0
#            astrometric_n_obs_ac   int16                                                                                      Total number of observations in the across-scan (AC) direction     0
#       astrometric_n_good_obs_al   int16                                                                                        Number of good observations in the along-scan (AL) direction     0
#        astrometric_n_bad_obs_al   int16                                                                                         Number of bad observations in the along-scan (AL) direction     0
#              astrometric_gof_al float32                                                                                      Goodness of fit statistic of model wrt along-scan observations     0
#             astrometric_chi2_al float32                                                                                                                                 AL chi-square value     0
#        astrometric_excess_noise float32           mas                                                                                                            Excess noise of the source     0
#    astrometric_excess_noise_sig float32                                                                                                                        Significance of excess noise     0
#       astrometric_params_solved   int16                                                                                                              Which parameters have been solved for?     0
#        astrometric_primary_flag    bool                                                                                                                                 Primary or seconday     0
#       nu_eff_used_in_astrometry float32        1 / um                                                                   Effective wavenumber of the source used in the astrometric solution    23
#                    pseudocolour float32        1 / um                                                                                  Astrometrically estimated pseudocolour of the source    33
#              pseudocolour_error float32        1 / um                                                                                      Standard error of the pseudocolour of the source    33
#            ra_pseudocolour_corr float32                                                                                                Correlation between right ascension and pseudocolour    33
#           dec_pseudocolour_corr float32                                                                                                    Correlation between declination and pseudocolour    33
#      parallax_pseudocolour_corr float32                                                                                                       Correlation between parallax and pseudocolour    33
#          pmra_pseudocolour_corr float32                                                                                Correlation between proper motion in right asension and pseudocolour    33
#         pmdec_pseudocolour_corr float32                                                                                   Correlation between proper motion in declination and pseudocolour    33
#    astrometric_matched_transits   int16                                                                                                      Matched FOV transits used in the AGIS solution     0
#         visibility_periods_used   int16                                                                                           Number of visibility periods used in Astrometric solution     0
#         astrometric_sigma5d_max float32           mas                                                                                The longest semi-major axis of the 5-d error ellipsoid     0
#                matched_transits   int16                                                                                                       The number of transits matched to this source     0
#            new_matched_transits   int16                                                              The number of transits newly incorporated into an existing source in the current cycle     0
#        matched_transits_removed   int16                                                                         The number of transits removed from an existing source in the current cycle     0
#      ipd_gof_harmonic_amplitude float32                                                                                              Amplitude of the IPD GoF versus position angle of scan     0
#          ipd_gof_harmonic_phase float32           deg                                                                                    Phase of the IPD GoF versus position angle of scan     0
#             ipd_frac_multi_peak   int16                                                                                           Percent of successful-IPD windows with more than one peak     0
#                ipd_frac_odd_win   int16                                                                                         Percent of transits with truncated windows or multiple gate     0
#                            ruwe float32                                                                                                                      Renormalised unit weight error     6
#      scan_direction_strength_k1 float32                                                                                        Degree of concentration of scan directions across the source     1
#      scan_direction_strength_k2 float32                                                                                        Degree of concentration of scan directions across the source     1
#      scan_direction_strength_k3 float32                                                                                        Degree of concentration of scan directions across the source     1
#      scan_direction_strength_k4 float32                                                                                        Degree of concentration of scan directions across the source     1
#          scan_direction_mean_k1 float32           deg                                                                              Mean position angle of scan directions across the source     1
#          scan_direction_mean_k2 float32           deg                                                                              Mean position angle of scan directions across the source     1
#          scan_direction_mean_k3 float32           deg                                                                              Mean position angle of scan directions across the source     1
#          scan_direction_mean_k4 float32           deg                                                                              Mean position angle of scan directions across the source     1
#               duplicated_source    bool                                                                                                             Source with multiple source identifiers     0
#                    phot_g_n_obs   int16                                                                                                 Number of observations contributing to G photometry     0
#                phot_g_mean_flux float64  electron / s                                                                                                                      G-band mean flux     0
#          phot_g_mean_flux_error float32  electron / s                                                                                                             Error on G-band mean flux     0
#     phot_g_mean_flux_over_error float32                                                                                                               G-band mean flux divided by its error     0
#                 phot_g_mean_mag float32           mag                                                                                                                 G-band mean magnitude     0
#                   phot_bp_n_obs   int16                                                                                                Number of observations contributing to BP photometry     0
#               phot_bp_mean_flux float64  electron / s                                                                                                               Integrated BP mean flux     0
#         phot_bp_mean_flux_error float32  electron / s                                                                                                  Error on the integrated BP mean flux     0
#    phot_bp_mean_flux_over_error float32                                                                                                        Integrated BP mean flux divided by its error     0
#                phot_bp_mean_mag float32           mag                                                                                                          Integrated BP mean magnitude     0
#                   phot_rp_n_obs   int16                                                                                                Number of observations contributing to RP photometry     0
#               phot_rp_mean_flux float64  electron / s                                                                                                               Integrated RP mean flux     0
#         phot_rp_mean_flux_error float32  electron / s                                                                                                  Error on the integrated RP mean flux     0
#    phot_rp_mean_flux_over_error float32                                                                                                        Integrated RP mean flux divided by its error     0
#                phot_rp_mean_mag float32           mag                                                                                                          Integrated RP mean magnitude     0
#        phot_bp_rp_excess_factor float32                                                                                                                                 BP/RP excess factor     0
# phot_bp_n_contaminated_transits   int16                                                                                                                  Number of BP contaminated transits     0
#      phot_bp_n_blended_transits   int16                                                                                                                       Number of BP blended transits     0
# phot_rp_n_contaminated_transits   int16                                                                                                                  Number of RP contaminated transits     0
#      phot_rp_n_blended_transits   int16                                                                                                                       Number of RP blended transits     0
#                  phot_proc_mode   int16                                                                                                                          Photometry processing mode     0
#                           bp_rp float32           mag                                                                                                                        BP - RP colour     0
#                            bp_g float32           mag                                                                                                                         BP - G colour     0
#                            g_rp float32           mag                                                                                                                         G - RP colour     0
#                 radial_velocity float32        km / s                                                                                                                       Radial velocity    50
#           radial_velocity_error float32        km / s                                                                                                                 Radial velocity error    50
#                  rv_method_used   int16                                                                                                           Method used to obtain the radial velocity    50
#                  rv_nb_transits   int16                                                                                              Number of transits used to compute the radial velocity    50
#        rv_nb_deblended_transits   int16                                                                                             Number of valid transits that have undergone deblending    50
#      rv_visibility_periods_used   int16                                                                                   Number of visibility periods used to estimate the radial velocity    50
#        rv_expected_sig_to_noise float32                                                 Expected signal to noise ratio in the combination of the spectra used to obtain the radial velocity    50
#             rv_renormalised_gof float32                                                                                                        Radial velocity renormalised goodness of fit    50
#                 rv_chisq_pvalue float32                                                                                              P-value for constancy based on a chi-squared criterion    50
#                rv_time_duration float32             d                                                                                      Time coverage of the radial velocity time series    50
#             rv_amplitude_robust float32        km / s                                                              Total amplitude in the radial velocity time series after outlier removal    50
#                rv_template_teff float32             K                                                                              Teff of the template used to compute the radial velocity    50
#                rv_template_logg float32 log(cm.s**-2)                                                                              Logg of the template used to compute the radial velocity    50
#                rv_template_fe_h float32           dex                                                                           [Fe/H] of the template used to compute the radial velocityy    50
#             rv_atm_param_origin   int16                                                                                     Origin of the atmospheric parameters associated to the template    50
#                          vbroad float32        km / s                                                                                                    Spectral line broadening parameter    50
#                    vbroad_error float32        km / s                                                                                           Uncertainty on the spectral line broadening    50
#              vbroad_nb_transits   int16                                                                                                           Number of transits used to compute vbroad    50
#                        grvs_mag float32           mag                                                                                                             Integrated Grvs magnitude    50
#                  grvs_mag_error float32           mag                                                                                                            Grvs magnitude uncertainty    50
#            grvs_mag_nb_transits   int16                                                                                                             Number of transits used to compute Grvs    50
#           rvs_spec_sig_to_noise float32                                                                                                      Signal to noise ratio in the mean RVS spectrum    50
#              phot_variable_flag  object                                                                                                                        Photometric variability flag     0
#                               l float64           deg                                                                                                                    Galactic longitude     0
#                               b float64           deg                                                                                                                     Galactic latitude     0
#                         ecl_lon float64           deg                                                                                                                    Ecliptic longitude     0
#                         ecl_lat float64           deg                                                                                                                     Ecliptic latitude     0
#               in_qso_candidates    bool                                                              Flag indicating the availability of additional information in the QSO candidates table     0
#            in_galaxy_candidates    bool                                                           Flag indicating the availability of additional information in the galaxy candidates table     0
#                 non_single_star   int16                                                    Flag indicating the availability of additional information in the various Non-Single Star tables     0
#               has_xp_continuous    bool                                                Flag indicating the availability of mean BP/RP spectrum in continuous representation for this source     0
#                  has_xp_sampled    bool                                                             Flag indicating the availability of mean BP/RP spectrum in sampled form for this source     0
#                         has_rvs    bool                                                                               Flag indicating the availability of mean RVS spectrum for this source     0
#            has_epoch_photometry    bool                                                                                Flag indicating the availability of epoch photometry for this source     0
#                    has_epoch_rv    bool                                                                           Flag indicating the availability of epoch radial velocity for this source     0
#                has_mcmc_gspphot    bool                                                                           Flag indicating the availability of GSP-Phot MCMC samples for this source     0
#                    has_mcmc_msc    bool                                                                                Flag indicating the availability of MSC MCMC samples for this source     0
#             in_andromeda_survey    bool                                                          Flag indicating that the source is present in the Gaia Andromeda Photometric Survey (GAPS)     0
#    classprob_dsc_combmod_quasar float32                                                  Probability from DSC-Combmod of being a quasar (data used: BP/RP spectrum, photometry, astrometry)     0
#    classprob_dsc_combmod_galaxy float32                                                  Probability from DSC-Combmod of being a galaxy (data used: BP/RP spectrum, photometry, astrometry)     0
#      classprob_dsc_combmod_star float32                     Probability from DSC-Combmod of being a single star (but not a white dwarf) (data used: BP/RP spectrum, photometry, astrometry)     0
#                    teff_gspphot float32             K                                                           Effective temperature from GSP-Phot Aeneas best library using BP/RP spectra    31
#              teff_gspphot_lower float32             K                           Lower confidence level (16%) of effective temperature from GSP-Phot Aeneas best library using BP/RP spectra    31
#              teff_gspphot_upper float32             K                           Upper confidence level (84%) of effective temperature from GSP-Phot Aeneas best library using BP/RP spectra    31
#                    logg_gspphot float32 log(cm.s**-2)                                                                 Surface gravity from GSP-Phot Aeneas best library using BP/RP spectra    31
#              logg_gspphot_lower float32 log(cm.s**-2)                                 Lower confidence level (16%) of surface gravity from GSP-Phot Aeneas best library using BP/RP spectra    31
#              logg_gspphot_upper float32 log(cm.s**-2)                                 Upper confidence level (84%) of surface gravity from GSP-Phot Aeneas best library using BP/RP spectra    31
#                      mh_gspphot float32           dex                                                                  Iron abundance from GSP-Phot Aeneas best library using BP/RP spectra    31
#                mh_gspphot_lower float32           dex                                  Lower confidence level (16%) of iron abundance from GSP-Phot Aeneas best library using BP/RP spectra    31
#                mh_gspphot_upper float32           dex                                  Upper confidence level (84%) of iron abundance from GSP-Phot Aeneas best library using BP/RP spectra    31
#                distance_gspphot float32            pc                                                                        Distance from GSP-Phot Aeneas best library using BP/RP spectra    31
#          distance_gspphot_lower float32            pc                                        Lower confidence level (16%) of distance from GSP-Phot Aeneas best library using BP/RP spectra    31
#          distance_gspphot_upper float32            pc                                        Upper confidence level (84%) of distance from GSP-Phot Aeneas best library using BP/RP spectra    31
#                   azero_gspphot float32           mag                                       Monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra    31
#             azero_gspphot_lower float32           mag       Lower confidence level (16%) of monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra    31
#             azero_gspphot_upper float32           mag       Upper confidence level (84%) of monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra    31
#                      ag_gspphot float32           mag                                                            Extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra    31
#                ag_gspphot_lower float32           mag                            Lower confidence level (16%) of extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra    31
#                ag_gspphot_upper float32           mag                            Upper confidence level (84%) of extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra    31
#                ebpminrp_gspphot float32           mag                                          Reddening $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra    31
#          ebpminrp_gspphot_lower float32           mag         Lower confidence level (16%) of reddening  $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra    31
#          ebpminrp_gspphot_upper float32           mag         Upper confidence level (84%) of reddening  $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra    31
#                 libname_gspphot  object               Name of library that achieves the highest mean log-posterior in MCMC samples and was used to derive GSP-Phot parameters in this table     0
#                            dist float64                                                                                                                                                         0
